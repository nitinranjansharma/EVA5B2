# %% [markdown]
# <a href="https://colab.research.google.com/github/nitinranjansharma/EVA5B2/blob/main/S15_1/full_model_train_test_nrs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! git clone https://github.com/nitinranjansharma/EVA5B2.git
# Out:
# Cloning into 'EVA5B2'...
# remote: Enumerating objects: 902, done.
# remote: Counting objects: 100% (397/397), done.
# remote: Compressing objects: 100% (342/342), done.
# remote: Total 902 (delta 139), reused 235 (delta 39), pack-reused 505
# Receiving objects: 100% (902/902), 44.80 MiB | 29.58 MiB/s, done.
# Resolving deltas: 100% (304/304), done.

# %%
! cp -r '/content/drive/MyDrive/EVA4B2/S15_1/weights' '/content/EVA5B2/S15_1'

# %%
! cp -r '/content/drive/MyDrive/EVA4B2/S15_1/data/data.zip' '/content/EVA5B2/S15_1'

# %%
#!unzip '/content/EVA5B2/S15_1/data.zip' -d '/content/EVA5B2/S15_1/data/'

# %%
'''
# !pip install pytorch-lightning
# !pip install pytorch-lightning==1.2.10
! pip install torchvision
# !pip install git+https://github.com/longcw/RoIAlign.pytorch -q
# !pip install --upgrade albumentations  # 0.5.2
'''
# Out:
# '\n!pip install pytorch-lightning\n!pip install pytorch-lightning==1.2.10\n! pip install torchvision\n!pip install git+https://github.com/longcw/RoIAlign.pytorch -q\n!pip install --upgrade albumentations  # 0.5.2\n'

# %%
# %cd /content/EVA5B2/S15_1
# Out:
# /content/EVA5B2/S15_1

# %%
from model_update.config import Config, PlaneRCNNConfig
from model_update.dataset import ComboDataset, PlaneRCNNDataset, MidasDataset
from model_update.model import Model
import matplotlib.pyplot as plt
import torch
import pytorch_lightning as pl

# %%
c = Config(
    USE_YOLO=True,
    DATA_DIR="data",
    IMG_SIZE=640,
    MIN_IMG_SIZE=480,
    BATCH_SIZE=1,
    MIDAS_LOSS_WEIGHT=1,
    PLANERCNN_LOSS_WEIGHT=1,
    PREDICT_DEPTH=False,
    EPOCHS=30
)

# %%
#c = Config()
d = ComboDataset(c)
loader = torch.utils.data.DataLoader(d, batch_size=1, shuffle=True, collate_fn=d.collate_fn)
loader_val = torch.utils.data.DataLoader(ComboDataset(c, train=False), batch_size=1, collate_fn=d.collate_fn)
# Out:
# Caching labels data/yolo/labels.npy (1001 found, 0 missing, 14 empty, 0 duplicate, for 1015 images): 100%|██████████| 1015/1015 [00:00<00:00, 9021.27it/s]
# Caching labels data/yolo/labels.npy (99 found, 0 missing, 0 empty, 0 duplicate, for 99 images): 100%|██████████| 99/99 [00:00<00:00, 5830.58it/s]

# %%
model = Model(c, 1, 4, d.yolo_dataset.yolo_labels)
# Out:
# Loading weights:  weights/midas.pt
# Downloading: "https://github.com/facebookresearch/WSL-Images/archive/master.zip" to /root/.cache/torch/hub/master.zip
# Downloading: "https://download.pytorch.org/models/ig_resnext101_32x8-c38310e5.pth" to /root/.cache/torch/hub/checkpoints/ig_resnext101_32x8-c38310e5.pth
# ...
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 147 layers, 5.93877e+07 parameters, 5.93877e+07 gradients
# Downloading: "https://github.com/ultralytics/yolov3/archive/master.zip" to /root/.cache/torch/hub/master.zip
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv3, attempting auto-update...
#                  from  n    params  module                                  arguments
#   0                -1  1       928  models.common.Conv                      [3, 32, 3, 1]
# ...

# %%
#training  - dont run 
'''
trainer = pl.Trainer(max_epochs=c.EPOCHS, gpus=1)
trainer.fit(
    model,
    train_dataloader=loader,
    val_dataloaders=loader_val
)
'''
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                   | Type          | Params
# ---------------------------------------------------------
# 0 | midas_net              | MidasNet      | 105 M
# 1 | yolo_part              | YoloPart      | 64.5 M
# 2 | planercnn_model        | MaskRCNN      | 24.3 M
# 3 | planercnn_refine_model | RefineModel   | 979 K
# 4 | planercnn_head         | PlaneRCNNHead | 78.0 M
# ---------------------------------------------------------
# 167 M     Trainable params
# 105 M     Non-trainable params
# 273 M     Total params
# 1,092.801 Total estimated model params size (MB)
# ...
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3328: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# ...

# %%
## saving model keys
# torch.save(model.state_dict(), 'trained_model.bin')

# %%
#! cp '/content/EVA5B2/S15_1/trained_model.bin' '/content/drive/MyDrive/EVA4B2'

# %% [markdown]
# ## Load model and Test and Experimentation

# %%
PATH = '/content/drive/MyDrive/EVA4B2/trained_model.bin'

model.load_state_dict(torch.load(PATH))
#model.eval()
# Out:
# <All keys matched successfully>

# %%
sample_img = next(iter(loader_val))
len(sample_img)
l1, l2, l3, l4, midas_out = model.midas_net(sample_img[0])
# Out:
# 4

# %%
print(sample_img[0].shape)  #image  
print(len(sample_img[1]))   # midas
print(len(sample_img[2]))   # yolo - image label path shapes pad
print(len(sample_img[3]))   # planercnn
# Out:
# torch.Size([1, 3, 256, 640])
# 2
# 5
# 1

# %%
model.training = False

# %%
#model_obj = model(sample_img[0])
l1, l2, l3, l4, midas_out = model.midas_net(sample_img[0])

# %%
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
print(midas_out.numpy().shape)
midas_out_img = midas_out.numpy().reshape(-1,640)
midas_out_img.shape
# Out:
# (1, 256, 640)
# (256, 640)

# %%
#from fox.yolov3.utils.torch_utils import ModelEMA
#yolo_ema = ModelEMA(model.yolo_part)
yolo_out = model.yolo_ema(l2)

#model.yolo_ema
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-89f0107fe5f6> in <module>()
#       1 #from fox.yolov3.utils.torch_utils import ModelEMA
#       2 #yolo_ema = ModelEMA(model.yolo_part)
# ----> 3 yolo_out = model.yolo_ema(l2)
#       4
#       5 #model.yolo_ema
#
# TypeError: 'ModelEMA' object is not callable

# %%
yolo_out = model.yolo_part(l2)
print(type(yolo_out))
print(len(yolo_out))
# Out:
# <class 'list'>
# 3

# %%
print(yolo_out[0].shape)
print(yolo_out[1].shape)
print(yolo_out[2].shape)
# Out:
# torch.Size([1, 3, 8, 20, 9])
# torch.Size([1, 3, 16, 40, 9])
# torch.Size([1, 3, 32, 80, 9])

# %%
from fox.yolov3.utils.utils import (
    labels_to_class_weights,
    non_max_suppression,
    output_to_target,
)
inf_out, _ ,_= yolo_out

# %%
p = yolo_out
ft = torch.cuda.FloatTensor if p[0].is_cuda else torch.Tensor
lcls, lbox, lobj = ft([0]), ft([0]), ft([0])

# %%
from fox.yolov3.utils.torch_utils import ModelEMA

# %%
yolo_ema = ModelEMA(model.yolo_part)
temp_yolo_part = yolo_ema.ema(l2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-a990ec523c92> in <module>()
#       1 yolo_ema = ModelEMA(model.yolo_part)
# ----> 2 temp_yolo_part = yolo_ema.ema(l2)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /content/EVA5B2/S15_1/fox/model.py in forward(self, x)
#      76     def forward(self, x):
#      77         yolo_head_out = self.yolo_head(x)
# ---> 78         return self.yolo_detector(yolo_head_out, x)
#      79
#      80
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
# ...

# %%
print(lcls, lbox, lobj)
# Out:
# tensor([0.]) tensor([0.]) tensor([0.])

# %%
import cv2
img = cv2.imread('/content/EVA5B2/S15_1/data/_112919912_gettyimages-1220030093.jpg')

# %%
print(img.shape)
img = img.reshape(-1,3,549,976).shape
# Out:
# (549, 976, 3)

# %%
model.predict(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-a59b8e0bb15a> in <module>()
# ----> 1 model.predict(img)
#
# AttributeError: 'collections.OrderedDict' object has no attribute 'predict'

# %%
import cv2
img = cv2.imread('/content/EVA5B2/S15_1/data/images/img_010.jpg')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-410172300156> in <module>()
# ----> 1 model.load_state_dict(torch.load(PATH))
#       2 model.eval()
#
# AttributeError: 'collections.OrderedDict' object has no attribute 'load_state_dict'

# %%
import cv2
img = cv2.imread('/content/EVA5B2/S15_1/data/images/img_010.jpg')

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
img =torch.tensor(img, device=device).float()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-58c20c53eaf8> in <module>()
#       1 device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# ----> 2 img =torch.tensor(img, device=device).float()
#
# RuntimeError: Could not infer dtype of NoneType

# %%
## prepare data for prediction

model.predict(img)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-30-361b111df1b6> in <module>()
# ----> 1 model.predict(img,0)
#
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/core/lightning.py in predict(self, batch, batch_idx, dataloader_idx)
#    1048         Use this function with trainer.predict(...). Override if you need to add any processing logic.
#    1049         """
# -> 1050         return self(batch)
#    1051
#    1052     def configure_callbacks(self):
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ...

# %%
## yolo
from fox.utils import plot_yolo_bbox, construct_midas_depth, visualize_planercnn, visualize_planercnn_batch
from PIL import Image
from matplotlib import cm

model.training = False

sample_img = next(iter(loader_val))
len(sample_img)
l1, l2, l3, l4, midas_out = model.midas_net(sample_img[0])
a,b,c,d = sample_img  

from fox.yolov3.utils.torch_utils import ModelEMA
yolo_ema = ModelEMA(model.yolo_part)
s = yolo_ema.ema(l2)
inf_out,_ = s

from fox.yolov3.utils.utils import (
    labels_to_class_weights,
    non_max_suppression,
    output_to_target,
)

output = non_max_suppression(
                    inf_out,
                    conf_thres=model.config.yolo_config.opt.conf_thres,
                    iou_thres=model.config.yolo_config.opt.iou_thres,
                )

res_img = plot_yolo_bbox(
                    c[0],
                    output_to_target(output, c[0].shape[-1], c[0].shape[-2]),
                    names=["hardhat", "vest", "mask", "boots"],
                )



im = Image.fromarray(res_img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-c8145659f54b> in <module>()
#      13 from fox.yolov3.utils.torch_utils import ModelEMA
#      14 yolo_ema = ModelEMA(model.yolo_part)
# ---> 15 s = yolo_ema.ema(l2)
#      16 inf_out,_ = s
#      17
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /content/EVA5B2/S15_1/fox/model.py in forward(self, x)
#      76     def forward(self, x):
#      77         yolo_head_out = self.yolo_head(x)
# ---> 78         return self.yolo_detector(yolo_head_out, x)
#      79
#      80
#
# ...

# %%
## planercnn
model.to('cpu')
model.training = False
sample_img = next(iter(loader_val))
len(sample_img)

l1, l2, l3, l4, midas_out = model.midas_net(sample_img[0])
a,b,c,d = sample_img

# %%
#model.planercnn_trainer
len(d)
d[0][0].shape
# Out:
# torch.Size([1, 3, 640, 640])

# %%
#device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#model.to(device)

# %%
extractor_outputs = [l1, l2, l3, l4] 
inp1 = [[o[i].unsqueeze(0).cuda() for o in extractor_outputs], d[0]]

x = inp1[0] # either the molded images or the stages of the feature extractor
image_metas = inp1[1]

# %%
[p2_out, p3_out, p4_out, p5_out, p6_out] = model.planercnn_model.fpn(x)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3328: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")

# %%
'''
l1 = l1.cuda()
l2 = l2.cuda()
l3 = l3.cuda()
l4 = l4.cuda()
'''

model.planercnn_model.predict_on_batch(
                [l1.cuda(), l2.cuda(), l3.cuda(), l4.cuda()],
                d,
                mode= "inference_detection",
                use_nms=2,
                use_refinement="refinement"
                in model.config.planercnn_config.options.suffix,
            )
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3328: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3458: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-111-8a435ea528e9> in <module>()
#      12                 use_nms=2,
#      13                 use_refinement="refinement"
# ---> 14                 in model.config.planercnn_config.options.suffix,
# ...

# %%
model.planercnn_model.
# Out:
# <bound method DataHooks.predict_dataloader of Model(
#   (midas_net): MidasNet(
#     (pretrained): Module(
#       (layer1): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         (4): Sequential(
#           (0): Bottleneck(
#             (conv1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv3): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
#!pip install torchviz
from torchviz import make_dot

x = torch.ones(1, 3, 224, 224, dtype=torch.float, requires_grad=False).cuda()
out = model(x)
make_dot(out)  # plot graph of variable, not of a nn.Module
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-118-1e7c3e94b48f> in <module>()
#       3
#       4 x = torch.ones(1, 3, 224, 224, dtype=torch.float, requires_grad=False).cuda()
# ----> 5 out = model(x)
#       6 make_dot(out)  # plot graph of variable, not of a nn.Module
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /content/EVA5B2/S15_1/fox/model.py in forward(self, x, planercnn_data, yolo_ema)
#     214                 yolo_out = self.yolo_part(l2)
#     215             else:
# --> 216                 yolo_out = yolo_ema(l2)
# ...
