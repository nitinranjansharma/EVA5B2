# %% [markdown]
# <a href="https://colab.research.google.com/github/nitinranjansharma/EVA5B2/blob/main/s12/S12_Assignment_cluster_result_annotation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
root_dir = "/content/drive/MyDrive/EVA4B2/assignment12/annotation/"
os.chdir(root_dir)

# %% [markdown]
# ## Usine coco json format downloaded from VGG extracted

# %%
from Annotator import Annotator

# %%
annotate = Annotator('annotation_nrs.json', 'results.csv')

# %%
annotate.show_bboxes()

# %%
annotate.create_cluster(10)

# %%
annotate.show_k(5)
# Out:
# Centroids: [[0.18906035 0.28187375]
#  [0.08961608 0.08618073]
#  [0.30625798 0.45573394]
#  [0.36641704 0.17179592]
#  [0.61976323 0.38107832]
#  [0.20611065 0.11984017]]
# Mean IOU: 0.6218911272819222

# %%
annotate.show_k(4)
# Out:
# Centroids: [[0.27864092 0.12112398]
#  [0.1969907  0.24627922]
#  [0.26566024 0.45637424]
#  [0.1068717  0.0892288 ]
#  [0.51731818 0.35124207]]
# Mean IOU: 0.600877701069384

# %%
annotate.show_k(6)
# Out:
# Centroids: [[0.08981924 0.08509939]
#  [0.35732505 0.16622659]
#  [0.34007824 0.35725497]
#  [0.20609951 0.11497557]
#  [0.1671334  0.25759702]
#  [0.23517202 0.50142955]
#  [0.61976323 0.38107832]]
# Mean IOU: 0.6340288866297398

# %% [markdown]
# ## Inference - It seems given the image sets annotations - we can consider 6 as number of clusters
